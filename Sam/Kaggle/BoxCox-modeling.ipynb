# %%
from myfunction import *

# %%
import pandas as pd
import numpy as np
all_data_=pd.read_csv("bx_all_data_onehot.csv")


bx_train_onehot=all_data_.iloc[:1460:,:] #train
bx_train_y_onehot=bx_train_onehot["SalePrice"]
bx_train_x_onehot=bx_train_onehot[bx_train_onehot.columns[bx_train_onehot.columns!="SalePrice"]]
bx_test_onehot=all_data_.iloc[1460:,:].drop(columns="SalePrice")

# %%
run_GB(bx_train_x_onehot,bx_train_y_onehot,bx_test_onehot,save=True)
#kaggle:0.13020
# Out:
# {'learning_rate': 0.001, 'loss': 'ls', 'max_depth': 4, 'max_features': 18, 'min_samples_split': 4, 'n_estimators': 10000}
# Lowest RMSE found:  25373.847933942496
# RMSE:  12191.477162632229

# %%
run_RF(bx_train_x_onehot,bx_train_y_onehot,bx_test_onehot,save=True)
#kaggle: 0.16197
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 1000, 'oob_score': True, 'random_state': 1}
# Lowest RMSE found:  31913.436735567364
# RMSE:  23652.021254546475

# %%
run_GLM(bx_train_x_onehot,bx_train_y_onehot,bx_test_onehot,save=True, ElasticNet=True)
#kaggle: 0.16834
# Out:
# C:\Users\samuelmao\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\samuelmao\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\samuelmao\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
run_GLM(bx_train_x_onehot,bx_train_y_onehot,bx_test_onehot,save=True, Lasso=True)
# Out:
# C:\Users\samuelmao\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\samuelmao\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\samuelmao\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
run_GLM(bx_train_x_onehot,bx_train_y_onehot,bx_test_onehot,save=True, Ridge=True)
# Out:
# {'alpha': 0.37649358067924676}
# Lowest RMSE found:  32670.978852037893
# RMSE:  27522.153425513392
